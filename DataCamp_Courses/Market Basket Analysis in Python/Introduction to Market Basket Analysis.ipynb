# %%
# Increase Jupyter display cell-width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %%
import pandas as pd

# Load transactions from Pandas
teleco = pd.read_csv('data/teleco_market_basket.csv')

# Print the header
print(teleco.head(2))
# Out:
#                          Item01     Item02     Item03  \
# 0                           NaN        NaN        NaN
# 1  Logitech M510 Wireless mouse  HP 63 Ink  HP 65 ink
#
#                        Item04                     Item05        Item06  \
# 0                         NaN                        NaN           NaN
# 1  nonda USB C to USB Adapter  10ft iPHone Charger Cable  HP 902XL ink
#
#                          Item07                               Item08  \
# 0                           NaN                                  NaN
# 1  Creative Pebble 2.0 Speakers  Cleaning Gel Universal Dust Cleaner
#
#                           Item09                                   Item10  \
# 0                            NaN                                      NaN
# 1  Micro Center 32GB Memory card  YUNSONG 3pack 6ft Nylon Lightning Cable
#
#                          Item11                     Item12  \
# 0                           NaN                        NaN
# ...

# %%
teleco.head(5)
# Out:
#                                       Item01  \
# 1               Logitech M510 Wireless mouse
# 2                                        NaN
# 3      Apple Lightning to Digital AV Adapter
# 4                                        NaN
# 5  UNEN Mfi Certified 5-pack Lightning Cable
#
#                              Item02        Item03                      Item04  \
# 1                         HP 63 Ink     HP 65 ink  nonda USB C to USB Adapter
# 2                               NaN           NaN                         NaN
# 3  TP-Link AC1750 Smart WiFi Router  Apple Pencil                         NaN
# 4                               NaN           NaN                         NaN
# 5                               NaN           NaN                         NaN
#
#                       Item05        Item06                        Item07  \
# 1  10ft iPHone Charger Cable  HP 902XL ink  Creative Pebble 2.0 Speakers
# 2                        NaN           NaN                           NaN
# ...

# %%
# delete a single row by index value 0
teleco = teleco.drop(labels=0, axis=0)

# %%
# Drop records with missing values
teleco.dropna(how='all', inplace=True)

# %%
insert_index = 0
insert_colname = 'Transaction'

# %%
teleco.head(5)
# Out:
#                                       Item01  \
# 1               Logitech M510 Wireless mouse
# 3      Apple Lightning to Digital AV Adapter
# 5  UNEN Mfi Certified 5-pack Lightning Cable
# 7                        Cat8 Ethernet Cable
# 9             Dust-Off Compressed Gas 2 pack
#
#                              Item02                      Item03  \
# 1                         HP 63 Ink                   HP 65 ink
# 3  TP-Link AC1750 Smart WiFi Router                Apple Pencil
# 5                               NaN                         NaN
# 7                         HP 65 ink                         NaN
# 9     Screen Mom Screen Cleaner kit  Moread HDMI to VGA Adapter
#
#                        Item04                     Item05        Item06  \
# 1  nonda USB C to USB Adapter  10ft iPHone Charger Cable  HP 902XL ink
# 3                         NaN                        NaN           NaN
# 5                         NaN                        NaN           NaN
# ...

# %%
# Create transaction column with ascending numbers
teleco.insert(0, 'Transaction', range(1, 1 + len(teleco)))
teleco.head()
# Out:
#        Transaction                                     Item01  \
# 1                1               Logitech M510 Wireless mouse
# 3                2      Apple Lightning to Digital AV Adapter
# 5                3  UNEN Mfi Certified 5-pack Lightning Cable
# 7                4                        Cat8 Ethernet Cable
# 9                5             Dust-Off Compressed Gas 2 pack
# ...            ...                                        ...
# 14993         7497               SanDisk 32GB Ultra SDHC card
# 14995         7498      Apple Lightning to Digital AV Adapter
# 14997         7499             Falcon Dust Off Compressed Gas
# 14999         7500                                HP 63XL Ink
# 15001         7501                               Apple Pencil
#
#                                      Item02                        Item03  \
# 1                                 HP 63 Ink                     HP 65 ink
# ...

# %%
# Split transaction strings into lists
transactions = teleco['Transaction'].apply(lambda t: t.split(','))
